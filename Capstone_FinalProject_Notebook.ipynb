# %%
## Capstone Final Project Notebook https://dataplatform.cloud.ibm.com/analytics/notebooks/v2/ea92e802-96d8-476b-8250-aa10e7b148b2/view?access_token=fdb2d050f94b5bfd148920cad6c019507a0592de1c52142cddb6b53d805c1d61

# %%
import pandas as pd
import numpy as np
print ("Hello Capstone Project Course")
# Out:
# Hello Capstone Project Course
